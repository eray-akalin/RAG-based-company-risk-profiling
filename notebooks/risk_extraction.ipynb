# %%
# !unzip colab_project.zip
# Out:
# Archive:  colab_project.zip
#   inflating: requirements.txt
#   inflating: config.py
#    creating: src/
#   inflating: src/comparator.py
#   inflating: src/chunker.py
#   inflating: src/retriever.py
#   inflating: src/collector.py
#  extracting: src/__init__.py
#    creating: src/__pycache__/
#   inflating: src/__pycache__/risk_extractor.cpython-312.pyc
#   inflating: src/__pycache__/collector.cpython-312.pyc
#   inflating: src/__pycache__/embedder.cpython-312.pyc
#   inflating: src/__pycache__/extractor.cpython-312.pyc
#   inflating: src/__pycache__/comparator.cpython-312.pyc
#   inflating: src/__pycache__/__init__.cpython-312.pyc
#   inflating: src/__pycache__/chunker.cpython-312.pyc
#   inflating: src/__pycache__/retriever.cpython-312.pyc
#   inflating: src/extractor.py
#   inflating: src/embedder.py
#   inflating: src/risk_extractor.py
#   inflating: src/evaluator.py
#    creating: prompts/
#   inflating: prompts/risk_extraction.py
#  extracting: prompts/__init__.py
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 97.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 90.6 MB/s eta 0:00:00
# ...

# %%
# !python src/risk_extractor.py
# Out:
# ...
# LLM Risk Profile Extractor
# Model: Qwen/Qwen2.5-3B-Instruct
# ...
# Loading model: Qwen/Qwen2.5-3B-Instruct
# Device: auto
# Auto-detected device: cuda
# config.json: 100% 661/661 [00:00<00:00, 3.90MB/s]
# ...
# tokenizer_config.json: 7.30kB [00:00, 26.0MB/s]
# vocab.json: 2.78MB [00:00, 49.1MB/s]
# merges.txt: 1.67MB [00:00, 91.0MB/s]
# tokenizer.json: 7.03MB [00:00, 113MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 35.6kB [00:00, 102MB/s]
# ...
# Fetching 2 files: 100% 2/2 [00:44<00:00, 22.20s/it]
# Download complete: 100% 6.17G/6.17G [00:44<00:00, 139MB/s]
# Loading weights: 100% 434/434 [00:19<00:00, 21.86it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.49MB/s]
# Model loaded successfully on cuda
#
# ...
# Extracting risk profile: Apple Inc. (AAPL)
# ...
# Loaded FAISS index: 1730 vectors
# Loaded metadata for 1730 chunks
# modules.json: 100% 349/349 [00:00<00:00, 2.36MB/s]
# ...
